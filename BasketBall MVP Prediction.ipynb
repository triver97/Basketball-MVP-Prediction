# %%
import pandas as pd

# %%
mvps = pd.read_excel("../Basketball MVP Prediction/mvps.xlsx")

# %%
mvps
# Out:
#     Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1     Michael Jordan   27  CHI     77      891      960  0.928  82
# 1      2      Magic Johnson   31  LAL     10      497      960  0.518  79
# 2      3     David Robinson   25  SAS      6      476      960  0.496  82
# 3      4    Charles Barkley   27  PHI      2      222      960  0.231  67
# 4      5        Karl Malone   27  UTA      0      142      960  0.148  82
# ..   ...                ...  ...  ...    ...      ...      ...    ...  ..
# 469   11  Russell Westbrook   32  WAS      0        5     1010  0.005  65
# 470   12        Ben Simmons   24  PHI      0        3     1010  0.003  58
# 471  13T       James Harden   31  TOT      0        1     1010  0.001  44
# 472  13T       LeBron James   36  LAL      0        1     1010  0.001  45
# 473  13T      Kawhi Leonard   29  LAC      0        1     1010  0.001  52
#
#        MP  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# ...

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991      891      960  0.928
# 1    Magic Johnson  1991      497      960  0.518
# 2   David Robinson  1991      476      960  0.496
# 3  Charles Barkley  1991      222      960  0.231
# 4      Karl Malone  1991      142      960  0.148

# %%
players =  pd.read_excel("../Basketball MVP Prediction/players.xlsx")

# %%
players
# Out:
#         Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0        1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...
# 1        2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...
# 2        3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...
# 3        4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...
# 4        5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...
# ...    ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
# 18039  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...
# 18040  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...
# 18041  538          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...
# 18042  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...
# 18043  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
del  players["Rk"]

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  0.474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  0.413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  0.509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  0.394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  0.462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3    3  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players.Player.head(25)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19           Miloš Babić
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23      Charles Barkley*
# 24           Dana Barros
# Name: Player, dtype: object

# %% [raw]
# Remove asterik because we want our data to match with other players name in mvps data

# %%
players["Player"] = players["Player"].str.replace("*","",regex= False)

# %%
players.head(20)
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0       Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  0.474  ...  0.6
# 1   Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  0.413  ...  0.5
# 2           Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  0.509  ...  2.1
# 3        Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  0.394  ...  0.9
# 4         Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  0.462  ...  1.7
# 5          Danny Ainge  SG  31  POR  80   0  21.4  4.2   8.9  0.472  ...  0.6
# 6          Mark Alarie  PF  27  WSB  42   1    14  2.4   5.4   0.44  ...    1
# 7         Steve Alford  PG  26  DAL  34   0   6.9  1.7   3.4  0.504  ...  0.3
# 8        Greg Anderson  PF  26  TOT  68   2  13.6  1.7     4   0.43  ...  1.4
# 9        Greg Anderson  PF  26  MIL  26   0   9.5    1   2.8   0.37  ...    1
# 10       Greg Anderson  PF  26  NJN   1   0    18    4     4      1  ...    4
# ...

# %% [raw]
# we see few players have multiple rows for same year we donot want that.

# %%
players.groupby(["Player","Year"]).get_group(("Greg Anderson",1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA   FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7    4  0.43  ...  1.4  3.3
# 9   Greg Anderson  PF  26  MIL  26  0   9.5    1  2.8  0.37  ...    1  1.9
# 10  Greg Anderson  PF  26  NJN   1  0    18    4    4     1  ...    4    2
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7  0.44  ...  1.6  4.1
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10    6    1    2    0    1    4    8  1991
# 11  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"] == 'TOT']
        row['Tm'] = df.iloc[-1,:]["Tm"]
        return row
    
players = players.groupby(["Player","Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73    30  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3    3   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8     4
# ...

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#           Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  DRB  \
# 164   A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  0.476  ...  2.5  3.8
# 633   A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  0.476  ...  3.7  5.6
# 1092  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  0.537  ...  3.5  5.2
# 1579  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  0.502  ...  3.4  5.8
# 2067  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  0.504  ...  2.4  5.8
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 164   6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 633   9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1092  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1579  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 2067  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %%
combined = players.merge(mvps, how = 'outer', on = ["Player","Year"])

# %%
combined.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  AST  STL  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.9  0.7
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  0.476  ...  1.4  1.1
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  0.537  ...  1.4  1.1
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  0.502  ...  1.7  0.9
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  0.504  ...  1.5  0.7
#
#    BLK  TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  0.3  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 1  0.4  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 2  0.5  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 3  0.5  1.2  1.7  14.7  1994     NaN     NaN   NaN
# 4  0.4  1.4  1.8  11.2  1995     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %%
combined[combined["Pts Won"] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 187     Al Jefferson      C  29  CHA  73  73    35   9.6  18.8  0.509  ...
# 329    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  0.416  ...
# 331    Allen Iverson     SG  23  PHI  48  48  41.5   9.1    22  0.412  ...
# 332    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  0.421  ...
# 333    Allen Iverson     SG  25  PHI  71  71    42  10.7  25.5   0.42  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...    ...  ...
# 13587   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  0.465  ...
# 13588   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1   0.46  ...
# 13592   Vince Carter  SF-SG  28  NJN  77  76  36.7     9    20  0.452  ...
# 13952       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  0.522  ...
# 13957       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  0.548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max  Share
# ...

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  AST  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.9
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  0.476  ...  1.4
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  0.537  ...  1.4
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  0.502  ...  1.7
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  0.504  ...  1.5
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 14087  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  0.505  ...  0.5
# 14088  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  0.552  ...  0.3
# 14089  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  0.442  ...  0.3
# 14090  Željko Rebrača   C  32  LAC  58   2    16  2.3     4  0.568  ...  0.4
# 14091  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  0.542  ...  0.3
#
# ...

# %%
teams = pd.read_excel("../Basketball MVP Prediction/teams.xlsx")

# %%
teams.head()
# Out:
#    Unnamed: 0   W   L   W/L%  GB   PS/G   PA/G   SRS  Year  \
# 0           0  56  26  0.683   —  111.5  105.7  5.22  1991
# 1           1  44  38  0.537  12  105.4  105.6 -0.39  1991
# 2           2  39  43  0.476  17  103.1  103.3 -0.43  1991
# 3           3  30  52  0.366  26  101.4  106.4 -4.84  1991
# 4           4  26  56  0.317  30  102.9  107.5 -4.53  1991
#
#                   Team
# 0      Boston Celtics*
# 1  Philadelphia 76ers*
# 2     New York Knicks*
# 3   Washington Bullets
# 4      New Jersey Nets

# %%
teams = teams[~teams["W"].str.contains("Division", na = False)]

# %%
teams["Team"] = teams["Team"].str.replace("*","",regex = False)

# %%
teams.head()
# Out:
#    Unnamed: 0   W   L   W/L%  GB   PS/G   PA/G   SRS  Year                Team
# 0           0  56  26  0.683   —  111.5  105.7  5.22  1991      Boston Celtics
# 1           1  44  38  0.537  12  105.4  105.6 -0.39  1991  Philadelphia 76ers
# 2           2  39  43  0.476  17  103.1  103.3 -0.43  1991     New York Knicks
# 3           3  30  52  0.366  26  101.4  106.4 -4.84  1991  Washington Bullets
# 4           4  26  56  0.317  30  102.9  107.5 -4.53  1991     New Jersey Nets

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combined["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'CHI', 'GSW', 'IND',
#        'WAS', 'MIN', 'BOS', 'HOU', 'DEN', 'ORL', 'NOH', 'TOR', 'SAC',
#        'CHO', 'POR', 'DET', 'PHI', 'UTA', 'MIL', 'VAN', 'SEA', 'NJN',
#        'NOK', 'LAC', 'OKC', 'ATL', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
nicknames = {}
with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev,name = line.replace("\n","").split(",")
        nicknames[abbrev] = name

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  0.476  ...  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  0.476  ...  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  0.537  ...  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  0.502  ...  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  0.504  ...  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share                Team
# 0  1.2  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.4  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.4  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.2  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
# 4  1.4  1.8  11.2  1995     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
train = combined.merge(teams, how="outer",on=["Team", "Year"])

# %%
train
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ... Share  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  0.476  ...   0.0
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  0.477  ...   0.0
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  0.455  ...   0.0
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9   0.34  ...   0.0
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  0.492  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...    ...  ...   ...
# 14087   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  0.484  ...   0.0
# 14088     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  0.286  ...   0.0
# 14089  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1   0.47  ...   0.0
# 14090      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  0.459  ...   0.0
# 14091      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  0.455  ...   0.0
#
# ...

# %%
del train["Unnamed: 0"]

# %%
train.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
train = train.apply(pd.to_numeric, errors='ignore')

# %%
train.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
train["GB"].unique()
# Out:
# array([5, 14, 23, 7, '—', 40, 42, 18, 6, 24, 26, 37, 29, 21, 28, 25, 8,
#        19, 1, 13, 17, 3, 15, 9, 2, 35, 20, 11, 16, 41, 12, 50, 10, 30, 34,
#        4, 1.5, 22, 51, 36, 43, 39, 18.5, 48, 46, 10.5, 32, 38, 27, 33, 31,
#        21.5, 45, 22.5, 25.5, 3.5, 20.5, 11.5, 44, 52, 56, 2.5, 12.5, 47,
#        32.5, 4.5], dtype=object)

# %%
train["GB"] = train["GB"].replace(to_replace = '—', value = 0, regex = True)

# %%
train["GB"].unique()
# Out:
# array([5, 14, 23, 7, 0, 40, 42, 18, 6, 24, 26, 37, 29, 21, 28, 25, 8, 19,
#        1, 13, 17, 3, 15, 9, 2, 35, 20, 11, 16, 41, 12, 50, 10, 30, 34, 4,
#        1.5, 22, 51, 36, 43, 39, 18.5, 48, 46, 10.5, 32, 38, 27, 33, 31,
#        21.5, 45, 22.5, 25.5, 3.5, 20.5, 11.5, 44, 52, 56, 2.5, 12.5, 47,
#        32.5, 4.5], dtype=object)

# %%
train["GB"] = pd.to_numeric(train["GB"])

# %%
train.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = train[train['G']>70].sort_values("PTS",ascending=False).head(10)

# %%
highest_scoring.plot.bar( "Player", "PTS")
# Out:
# <AxesSubplot:xlabel='Player'>

# %%
highest_scoring_by_year = train.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
highest_scoring_by_year.plot.bar("Year", "PTS")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
train.groupby("Year").apply(lambda x: x.shape[0])
# Out:
# Year
# 1991    385
# 1992    386
# 1993    390
# 1994    403
# 1995    405
# 1996    428
# 1997    441
# 1998    439
# 1999    440
# 2000    439
# 2001    441
# 2002    440
# 2003    428
# 2004    442
# 2005    464
# 2006    458
# 2007    458
# 2008    450
# 2009    443
# 2010    442
# 2011    452
# 2012    478
# 2013    467
# 2014    480
# 2015    492
# 2016    476
# 2017    486
# 2018    540
# 2019    530
# 2020    529
# 2021    540
# dtype: int64

# %%
train.corr()["Share"]
# Out:
# Age        0.018596
# G          0.089282
# GS         0.167476
# MP         0.162175
# FG         0.276365
# FGA        0.249254
# FG%        0.065789
# 3P         0.096225
# 3PA        0.096460
# 3P%        0.013611
# 2P         0.275976
# 2PA        0.251885
# 2P%        0.063240
# eFG%       0.059335
# FT         0.316392
# FTA        0.321457
# FT%        0.037875
# ORB        0.101375
# DRB        0.213241
# TRB        0.186209
# AST        0.200253
# STL        0.175041
# BLK        0.154713
# TOV        0.233015
# PF         0.071046
# PTS        0.288267
# Year      -0.008135
# Pts Won    0.995153
# Pts Max    0.521335
# Share      1.000000
# W          0.122718
# L         -0.121866
# W/L%       0.126559
# GB        -0.101014
# PS/G       0.045206
# PA/G      -0.039617
# SRS        0.122782
# Name: Share, dtype: float64

# %%
train.corr()["Share"].plot.bar()
# Out:
# <AxesSubplot:>

# %%
predictors = ["Age", "G", "GS", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']

# %%
train1 = train[~(train["Year"] == 2021)]

# %%
test = train[train["Year"] == 2021]

# %%
stats = pd.read_csv("../Basketball MVP Prediction/player_mvp_stats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14088       14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %%
del stats["Unnamed: 0"]

# %%
stats.isna().sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats[pd.isnull(stats["3P%"])][["Player", "3PA"]].head()
# Out:
#              Player  3PA
# 2    Elden Campbell  0.0
# 3     Irving Thomas  0.0
# 18       Jack Haley  0.0
# 20      Keith Owens  0.0
# 30  Benoit Benjamin  0.0

# %%
stats[pd.isnull(stats["FT%"])][["Player", "FTA"]].head()
# Out:
#               Player  FTA
# 77        John Coker  0.0
# 92      Jason Sasser  0.0
# 103  Adrian Caldwell  0.0
# 119     Bruno Šundov  0.0
# 158   Jamal Robinson  0.0

# %%
stats = stats.fillna(0)

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
stats.GB.head(56)
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
# 5      5
# 6      5
# 7      5
# 8      5
# 9      5
# 10     5
# 11     5
# 12    14
# 13    14
# 14    14
# 15    14
# 16    14
# 17    14
# 18    14
# 19    14
# 20    14
# 21    14
# 22    14
# 23    14
# 24    14
# 25    14
# 26    14
# 27    23
# 28    23
# 29    23
# 30    23
# 31    23
# 32    23
# 33    23
# 34    23
# 35    23
# 36    23
# 37    23
# 38    23
# 39    23
# 40     7
# 41     7
# 42     7
# 43     7
# 44     7
# 45     7
# 46     7
# 47     7
# 48     7
# 49     7
# 50     7
# 51     7
# 52     7
# 53     7
# 54     7
# 55     —
# Name: GB, dtype: object

# %%
stats["GB"] = stats["GB"].replace(to_replace = '—', value = 0, regex = True)

# %%
stats["GB"] = pd.to_numeric(stats["GB"])

# %%
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
        'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
train1 = stats[stats["Year"] < 2021]

# %%
test = stats[stats["Year"] == 2021]

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha = 0.1)

# %%
X = train1[predictors]

# %%
y = train1["Share"]

# %%
reg.fit(X,y)
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
predictions
# Out:
#        predictions
# 630       0.013567
# 631      -0.013756
# 632       0.002414
# 633      -0.004421
# 634       0.010734
# ...            ...
# 13897    -0.012571
# 13898    -0.011575
# 13899     0.016424
# 13900    -0.020434
# 13901    -0.005421
#
# [540 rows x 1 columns]

# %%
combination1 = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination1.sort_values("Share", ascending=False).head(20)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.154307
# 8624             Joel Embiid  0.580     0.162713
# 3651           Stephen Curry  0.449     0.142386
# 9907   Giannis Antetokounmpo  0.345     0.207436
# 1389              Chris Paul  0.138     0.072294
# 10997            Luka Dončić  0.042     0.151430
# 7464          Damian Lillard  0.038     0.116303
# 3536           Julius Randle  0.020     0.088878
# 3531            Derrick Rose  0.010     0.033000
# 11358            Rudy Gobert  0.008     0.095349
# 3876       Russell Westbrook  0.005     0.120228
# 8616             Ben Simmons  0.003     0.062537
# 4174            James Harden  0.001     0.140598
# 5328           Kawhi Leonard  0.001     0.113350
# 3736            LeBron James  0.001     0.147511
# 9909             Jeff Teague  0.000    -0.009504
# 10672        Jalen McDaniels  0.000    -0.011461
# 10671           Grant Riller  0.000    -0.004844
# ...

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(combination1["Share"], combination1["predictions"])
# Out:
# 0.002666895456710413

# %%
combination1["Share"].value_counts()
# Out:
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.010      1
# 0.020      1
# 0.449      1
# 0.005      1
# 0.038      1
# 0.003      1
# 0.580      1
# 0.345      1
# 0.042      1
# 0.008      1
# Name: Share, dtype: int64

# %% [raw]
# this error metric doesn't make sense because 525 didn't get any votes and we care about top 5 MVP vote getters. 99% players donot get any MVP votes

# %%
actual = combination1.sort_values("Share", ascending=False)
predicted = combination1.sort_values("predictions", ascending=False)
actual["Rk"] = list(range(1,actual.shape[0]+1))
predicted["Predicted_Rk"] = list(range(1,predicted.shape[0]+1))

# %%
actual.merge(predicted, on="Player").head(5)
# Out:
#                   Player  Share_x  predictions_x  Rk  Share_y  predictions_y  \
# 0           Nikola Jokić    0.961       0.154307   1    0.961       0.154307
# 1            Joel Embiid    0.580       0.162713   2    0.580       0.162713
# 2          Stephen Curry    0.449       0.142386   3    0.449       0.142386
# 3  Giannis Antetokounmpo    0.345       0.207436   4    0.345       0.207436
# 4             Chris Paul    0.138       0.072294   5    0.138       0.072294
#
#    Predicted_Rk
# 0             3
# 1             2
# 2             6
# 3             1
# 4            33

# %%
def find_ap(combination1):
    actual = combination1.sort_values("Share", ascending=False).head(5)
    predicted = combination1.sort_values("predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found / seen)
        seen += 1

    return sum(ps) / len(ps)

# %%
ap = find_ap(combination1)

# %%
ap
# Out:
# 0.7636363636363636

# %%
years = list(range(1991,2022))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps) / len(aps)
# Out:
# 0.7112884360789578

# %%
def add_ranks(predictions):
    predictions = predictions.sort_values("predictions", ascending=False)
    predictions["Predicted_Rk"] = list(range(1,predictions.shape[0]+1))
    predictions = predictions.sort_values("Share", ascending=False)
    predictions["Rk"] = list(range(1,predictions.shape[0]+1))
    predictions["Diff"] = (predictions["Rk"] - predictions["Predicted_Rk"])
    return predictions

# %%
add_ranks(all_predictions[1])
# Out:
#                 Player  Share  predictions  Predicted_Rk   Rk  Diff
# 1600       Karl Malone  0.857     0.192318             2    1    -1
# 10524   Michael Jordan  0.832     0.167629             3    2    -1
# 908         Grant Hill  0.327     0.128646             6    3    -3
# 4682      Tim Hardaway  0.207     0.059984            20    4   -16
# 8248         Glen Rice  0.117     0.033110            53    5   -48
# ...                ...    ...          ...           ...  ...   ...
# 10136   Horacio Llamas  0.000     0.010171           156  437   281
# 3576     Ennis Whatley  0.000     0.010250           155  438   283
# 10594  Kevin Salvadori  0.000     0.010553           154  439   285
# 1138    Aaron Williams  0.000     0.010594           153  440   287
# 6792     Melvin Booker  0.000    -0.055185           441  441     0
#
# [441 rows x 6 columns]

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps) / len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
all_predictions[all_predictions["Rk"] < 5].sort_values("Diff").head(10)
# Out:
#                 Player  Share  predictions  Predicted_Rk  Rk  Diff
# 1224        Jason Kidd  0.712     0.028209            52   2   -50
# 5175        Steve Nash  0.839     0.034100            45   1   -44
# 8516   Peja Stojaković  0.228     0.036269            38   4   -34
# 12726      Joakim Noah  0.258     0.046968            37   4   -33
# 5193        Steve Nash  0.739     0.054128            34   1   -33
# 5208        Steve Nash  0.785     0.074421            21   2   -19
# 4682      Tim Hardaway  0.207     0.059984            20   4   -16
# 937      Allen Iverson  0.270     0.072120            14   4   -10
# 6746       Kobe Bryant  0.291     0.078014            14   4   -10
# 1157       Gary Payton  0.372     0.076708            13   3   -10

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)

mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors + ["Pos", "Tm"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_77896/1519891261.py in <module>
#       3 rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)
#       4
# ----> 5 mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors + ["Pos", "Tm"])
#
# ~\AppData\Local\Temp/ipykernel_77896/1432808103.py in backtest(stats, model, years, predictors)
#       5         train = stats[stats["Year"] < year]
#       6         test = stats[stats["Year"] == year]
# ----> 7         model.fit(train[predictors],train["Share"])
#       8         predictions = model.predict(test[predictors])
#       9         predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
# ...
